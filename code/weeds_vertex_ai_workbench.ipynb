00:00,  1.41 url/s]
# Dl Completed...:  50%|█████     | 1/2 [03:07<00:00,  1.41 url/s]
# Dl Completed...:  50%|█████     | 1/2 [03:08<00:00,  1.41 url/s]
# Dl Completed...:  50%|█████     | 1/2 [03:09<00:00,  1.41 url/s]
# Dl Completed...:  50%|█████     | 1/2 [03:09<00:00,  1.41 url/s]
# Dl Completed...:  50%|█████     | 1/2 [03:10<00:00,  1.41 url/s]
# Dl Completed...:  50%|█████     | 1/2 [03:11<00:00,  1.41 url/s]
# Dl Completed...:  50%|█████     | 1/2 [03:12<00:00,  1.41 url/s]
# Dl Completed...:  50%|█████     | 1/2 [03:13<00:00,  1.41 url/s]
# Dl Completed...:  50%|█████     | 1/2 [03:14<00:00,  1.41 url/s]
# Dl Completed...:  50%|█████     | 1/2 [03:15<00:00,  1.41 url/s]
# Dl Completed...:  50%|█████     | 1/2 [03:15<00:00,  1.41 url/s]
# Dl Completed...:  50%|█████     | 1/2 [03:16<00:00,  1.41 url/s]
# Dl Completed...:  50%|█████     | 1/2 [03:17<00:00,  1.41 url/s]
# Dl Completed...:  50%|█████     | 1/2 [03:18<00:00,  1.41 url/s]
# Dl Completed...:  50%|█████     | 1/2 [03:18<00:00,  1.41 url/s]
# Dl Completed...:  50%|█████     | 1/2 [03:20<00:00,  1.41 url/s]
# Dl Completed...:  50%|█████     | 1/2 [03:20<00:00,  1.41 url/s]
# Dl Completed...:  50%|█████     | 1/2 [03:21<00:00,  1.41 url/s]
# Dl Completed...:  50%|█████     | 1/2 [03:22<00:00,  1.41 url/s]
# Dl Completed...:  50%|█████     | 1/2 [03:23<00:00,  1.41 url/s]
# Dl Completed...:  50%|█████     | 1/2 [03:24<00:00,  1.41 url/s]
# Dl Completed...:  50%|█████     | 1/2 [03:25<00:00,  1.41 url/s]
# Dl Completed...:  50%|█████     | 1/2 [03:26<00:00,  1.41 url/s]
# Dl Completed...:  50%|█████     | 1/2 [03:26<00:00,  1.41 url/s]
# Dl Completed...:  50%|█████     | 1/2 [03:27<00:00,  1.41 url/s]
# Dl Completed...:  50%|█████     | 1/2 [03:28<00:00,  1.41 url/s]
# Dl Completed...:  50%|█████     | 1/2 [03:29<00:00,  1.41 url/s]
# Dl Completed...:  50%|█████     | 1/2 [03:30<00:00,  1.41 url/s]
# Dl Completed...:  50%|█████     | 1/2 [03:31<00:00,  1.41 url/s]
# Dl Completed...:  50%|█████     | 1/2 [03:32<00:00,  1.41 url/s]
# Dl Completed...:  50%|█████     | 1/2 [03:33<00:00,  1.41 url/s]
# Dl Completed...:  50%|█████     | 1/2 [03:33<00:00,  1.41 url/s]
# Dl Completed...:  50%|█████     | 1/2 [03:34<00:00,  1.41 url/s]
# Dl Completed...:  50%|█████     | 1/2 [03:35<00:00,  1.41 url/s]
# Dl Completed...:  50%|█████     | 1/2 [03:36<00:00,  1.41 url/s]
# Dl Completed...:  50%|█████     | 1/2 [03:36<00:00,  1.41 url/s]
# Dl Completed...:  50%|█████     | 1/2 [03:37<00:00,  1.41 url/s]
# Dl Completed...:  50%|█████     | 1/2 [03:38<00:00,  1.41 url/s]
# Dl Completed...:  50%|█████     | 1/2 [03:39<00:00,  1.41 url/s]
# Dl Completed...:  50%|█████     | 1/2 [03:39<00:00,  1.41 url/s]
# Dl Completed...:  50%|█████     | 1/2 [03:40<00:00,  1.41 url/s]
# Dl Completed...:  50%|█████     | 1/2 [03:41<00:00,  1.41 url/s]
# Dl Completed...:  50%|█████     | 1/2 [03:41<00:00,  1.41 url/s]
# Dl Completed...:  50%|█████     | 1/2 [03:42<00:00,  1.41 url/s]
# Dl Completed...:  50%|█████     | 1/2 [03:43<00:00,  1.41 url/s]
# Dl Completed...:  50%|█████     | 1/2 [03:44<00:00,  1.41 url/s]
# Dl Completed...:  50%|█████     | 1/2 [03:45<00:00,  1.41 url/s]
# Dl Completed...:  50%|█████     | 1/2 [03:46<00:00,  1.41 url/s]
# Dl Completed...:  50%|█████     | 1/2 [03:47<00:00,  1.41 url/s]
# Dl Completed...:  50%|█████     | 1/2 [03:47<00:00,  1.41 url/s]
# Dl Completed...:  50%|█████     | 1/2 [03:48<00:00,  1.41 url/s]
# Dl Completed...:  50%|█████     | 1/2 [03:49<00:00,  1.41 url/s]
# Dl Completed...:  50%|█████     | 1/2 [03:50<00:00,  1.41 url/s]
# Dl Completed...:  50%|█████     | 1/2 [03:50<00:00,  1.41 url/s]
# Dl Completed...:  50%|█████     | 1/2 [03:51<00:00,  1.41 url/s]
# Dl Completed...:  50%|█████     | 1/2 [03:52<00:00,  1.41 url/s]
# Dl Completed...:  50%|█████     | 1/2 [03:53<00:00,  1.41 url/s]
# Dl Completed...:  50%|█████     | 1/2 [03:53<00:00,  1.41 url/s]
# Dl Completed...:  50%|█████     | 1/2 [03:54<00:00,  1.41 url/s]
# Dl Completed...:  50%|█████     | 1/2 [03:55<00:00,  1.41 url/s]
# Dl Completed...:  50%|█████     | 1/2 [03:55<00:00,  1.41 url/s]
# Dl Completed...:  50%|█████     | 1/2 [03:56<00:00,  1.41 url/s]
# Dl Completed...:  50%|█████     | 1/2 [03:56<00:00,  1.41 url/s]
# Dl Completed...:  50%|█████     | 1/2 [03:57<00:00,  1.41 url/s]
# Dl Completed...:  50%|█████     | 1/2 [03:58<00:00,  1.41 url/s]
# Dl Completed...:  50%|█████     | 1/2 [03:59<00:00,  1.41 url/s]
# Dl Completed...:  50%|█████     | 1/2 [03:59<00:00,  1.41 url/s]
# Dl Completed...:  50%|█████     | 1/2 [04:00<00:00,  1.41 url/s]
# Dl Completed...:  50%|█████     | 1/2 [04:01<00:00,  1.41 url/s]
# Dl Completed...:  50%|█████     | 1/2 [04:02<00:00,  1.41 url/s]
# Dl Completed...:  50%|█████     | 1/2 [04:03<00:00,  1.41 url/s]
# Dl Completed...:  50%|█████     | 1/2 [04:03<00:00,  1.41 url/s]
# Dl Completed...:  50%|█████     | 1/2 [04:04<00:00,  1.41 url/s]
# Dl Completed...:  50%|█████     | 1/2 [04:05<00:00,  1.41 url/s]
# Dl Completed...:  50%|█████     | 1/2 [04:05<00:00,  1.41 url/s]
# Dl Completed...:  50%|█████     | 1/2 [04:06<00:00,  1.41 url/s]
# Dl Completed...:  50%|█████     | 1/2 [04:07<00:00,  1.41 url/s]
# Dl Completed...:  50%|█████     | 1/2 [04:08<00:00,  1.41 url/s]
# Dl Completed...:  50%|█████     | 1/2 [04:08<00:00,  1.41 url/s]
# Dl Completed...:  50%|█████     | 1/2 [04:09<00:00,  1.41 url/s]
# Dl Completed...:  50%|█████     | 1/2 [04:10<00:00,  1.41 url/s]
# Dl Completed...:  50%|█████     | 1/2 [04:11<00:00,  1.41 url/s]
# Dl Completed...:  50%|█████     | 1/2 [04:11<00:00,  1.41 url/s]
# Dl Completed...:  50%|█████     | 1/2 [04:12<00:00,  1.41 url/s]
# Dl Completed...:  50%|█████     | 1/2 [04:13<00:00,  1.41 url/s]
# Dl Completed...:  50%|█████     | 1/2 [04:14<00:00,  1.41 url/s]
# Dl Completed...:  50%|█████     | 1/2 [04:15<00:00,  1.41 url/s]
# Dl Completed...:  50%|█████     | 1/2 [04:15<00:00,  1.41 url/s]
# Dl Completed...:  50%|█████     | 1/2 [04:16<00:00,  1.41 url/s]
# Dl Completed...:  50%|█████     | 1/2 [04:16<00:00,  1.41 url/s]
# Dl Completed...:  50%|█████     | 1/2 [04:17<00:00,  1.41 url/s]
# Dl Completed...:  50%|█████     | 1/2 [04:18<00:00,  1.41 url/s]
# Dl Completed...:  50%|█████     | 1/2 [04:19<00:00,  1.41 url/s]
# Dl Completed...:  50%|█████     | 1/2 [04:19<00:00,  1.41 url/s]
# Dl Completed...:  50%|█████     | 1/2 [04:20<00:00,  1.41 url/s]
# Dl Completed...:  50%|█████     | 1/2 [04:21<00:00,  1.41 url/s]
# Dl Completed...:  50%|█████     | 1/2 [04:22<00:00,  1.41 url/s]
# Dl Completed...:  50%|█████     | 1/2 [04:22<00:00,  1.41 url/s]
# Dl Completed...:  50%|█████     | 1/2 [04:23<00:00,  1.41 url/s]
# Dl Completed...:  50%|█████     | 1/2 [04:24<00:00,  1.41 url/s]
# Dl Completed...:  50%|█████     | 1/2 [04:25<00:00,  1.41 url/s]
# Dl Completed...:  50%|█████     | 1/2 [04:26<00:00,  1.41 url/s]
# Dl Completed...:  50%|█████     | 1/2 [04:27<00:00,  1.41 url/s]
# Dl Completed...:  50%|█████     | 1/2 [04:27<00:00,  1.41 url/s]
# Dl Completed...:  50%|█████     | 1/2 [04:28<00:00,  1.41 url/s]
# Dl Completed...:  50%|█████     | 1/2 [04:28<00:00,  1.41 url/s]
# Dl Completed...:  50%|█████     | 1/2 [04:29<00:00,  1.41 url/s]
# Dl Completed...:  50%|█████     | 1/2 [04:30<00:00,  1.41 url/s]
# Dl Completed...:  50%|█████     | 1/2 [04:31<00:00,  1.41 url/s]
# Dl Completed...:  50%|█████     | 1/2 [04:32<00:00,  1.41 url/s]
# Dl Completed...:  50%|█████     | 1/2 [04:32<00:00,  1.41 url/s]
# Dl Completed...:  50%|█████     | 1/2 [04:33<00:00,  1.41 url/s]
# Dl Completed...:  50%|█████     | 1/2 [04:34<00:00,  1.41 url/s]
# Dl Completed...:  50%|█████     | 1/2 [04:35<00:00,  1.41 url/s]
# Dl Completed...:  50%|█████     | 1/2 [04:36<00:00,  1.41 url/s]
# Dl Completed...:  50%|█████     | 1/2 [04:37<00:00,  1.41 url/s]
# Dl Completed...:  50%|█████     | 1/2 [04:37<00:00,  1.41 url/s]
# Dl Completed...:  50%|█████     | 1/2 [04:38<00:00,  1.41 url/s]
# Dl Completed...:  50%|█████     | 1/2 [04:39<00:00,  1.41 url/s]
# Dl Completed...:  50%|█████     | 1/2 [04:40<00:00,  1.41 url/s]
# Dl Completed...:  50%|█████     | 1/2 [04:41<00:00,  1.41 url/s]
# Dl Completed...:  50%|█████     | 1/2 [04:42<00:00,  1.41 url/s]
# Dl Completed...:  50%|█████     | 1/2 [04:44<00:00,  1.41 url/s]
# Extraction completed...: 0 file [04:44, ? file/s]
# Dl Size...:  84%|████████▍ | 392/468 [04:44<00:55,  1.38 MiB/s]
# Dl Completed...:  50%|█████     | 1/2 [04:44<04:44, 284.38s/ url]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/4k/y4ljh2217c57vl68z1zkl0440000gn/T/ipykernel_82112/1007210419.py in <module>
# ----> 1 data, info = tfds.load(name='deep_weeds', as_supervised=True, with_info=True)
#       2 NUM_CLASSES = info.features['label'].num_classes
#       3 DATASET_SIZE = info.splits['train'].num_examples
#
# ~/miniforge3/envs/pytorch_m1/lib/python3.8/site-packages/tensorflow_datasets/core/load.py in load(name, split, data_dir, batch_size, shuffle_files, download, as_supervised, decoders, read_config, with_info, builder_kwargs, download_and_prepare_kwargs, as_dataset_kwargs, try_gcs)
#     331   if download:
#     332     download_and_prepare_kwargs = download_and_prepare_kwargs or {}
# --> 333     dbuilder.download_and_prepare(**download_and_prepare_kwargs)
#     334
#     335   if as_dataset_kwargs is None:
#
# ~/miniforge3/envs/pytorch_m1/lib/python3.8/site-packages/tensorflow_datasets/core/dataset_builder.py in download_and_prepare(self, download_dir, download_config)
#     437           # Old version of TF are not os.PathLike compatible
#     438           with tf_compat.mock_gfile_pathlike():
# --> 439             self._download_and_prepare(
#     440                 dl_manager=dl_manager,
#     441                 download_config=download_config,
#
# ~/miniforge3/envs/pytorch_m1/lib/python3.8/site-packages/tensorflow_datasets/core/dataset_builder.py in _download_and_prepare(self, dl_manager, download_config)
#    1131       else:
#    1132         optional_pipeline_kwargs = {}
# -> 1133       split_generators = self._split_generators(  # pylint: disable=unexpected-keyword-arg
#    1134           dl_manager, **optional_pipeline_kwargs)
#    1135       # TODO(tfds): Could be removed once all datasets are migrated.
#
# ~/miniforge3/envs/pytorch_m1/lib/python3.8/site-packages/tensorflow_datasets/image_classification/deep_weeds.py in _split_generators(self, dl_manager)
#      89   def _split_generators(self, dl_manager):
#      90     """Define Splits."""
# ---> 91     paths = dl_manager.download_and_extract({
#      92         "image": _URL,
#      93         "label": _URL_LABELS})
#
# ~/miniforge3/envs/pytorch_m1/lib/python3.8/site-packages/tensorflow_datasets/core/download/download_manager.py in download_and_extract(self, url_or_urls)
#     635     with self._downloader.tqdm():
#     636       with self._extractor.tqdm():
# --> 637         return _map_promise(self._download_extract, url_or_urls)
#     638
#     639   @property
#
# ~/miniforge3/envs/pytorch_m1/lib/python3.8/site-packages/tensorflow_datasets/core/download/download_manager.py in _map_promise(map_fn, all_inputs)
#     776   """Map the function into each element and resolve the promise."""
#     777   all_promises = tf.nest.map_structure(map_fn, all_inputs)  # Apply the function
# --> 778   res = tf.nest.map_structure(lambda p: p.get(), all_promises)  # Wait promises
#     779   return res
#
# ~/miniforge3/envs/pytorch_m1/lib/python3.8/site-packages/tensorflow/python/util/nest.py in map_structure(func, *structure, **kwargs)
#     867
#     868   return pack_sequence_as(
# --> 869       structure[0], [func(*x) for x in entries],
#     870       expand_composites=expand_composites)
#     871
#
# ~/miniforge3/envs/pytorch_m1/lib/python3.8/site-packages/tensorflow/python/util/nest.py in <listcomp>(.0)
#     867
#     868   return pack_sequence_as(
# --> 869       structure[0], [func(*x) for x in entries],
#     870       expand_composites=expand_composites)
#     871
#
# ~/miniforge3/envs/pytorch_m1/lib/python3.8/site-packages/tensorflow_datasets/core/download/download_manager.py in <lambda>(p)
#     776   """Map the function into each element and resolve the promise."""
#     777   all_promises = tf.nest.map_structure(map_fn, all_inputs)  # Apply the function
# --> 778   res = tf.nest.map_structure(lambda p: p.get(), all_promises)  # Wait promises
#     779   return res
#
# ~/miniforge3/envs/pytorch_m1/lib/python3.8/site-packages/promise/promise.py in get(self, timeout)
#     509         # type: (Optional[float]) -> T
#     510         target = self._target()
# --> 511         self._wait(timeout or DEFAULT_TIMEOUT)
#     512         return self._target_settled_value(_raise=True)
#     513
#
# ~/miniforge3/envs/pytorch_m1/lib/python3.8/site-packages/promise/promise.py in _wait(self, timeout)
#     504     def _wait(self, timeout=None):
#     505         # type: (Optional[float]) -> None
# --> 506         self.wait(self, timeout)
#     507
#     508     def get(self, timeout=None):
#
# ~/miniforge3/envs/pytorch_m1/lib/python3.8/site-packages/promise/promise.py in wait(cls, promise, timeout)
#     500     def wait(cls, promise, timeout=None):
#     501         # type: (Promise, Optional[float]) -> None
# --> 502         async_instance.wait(promise, timeout)
#     503
#     504     def _wait(self, timeout=None):
#
# ~/miniforge3/envs/pytorch_m1/lib/python3.8/site-packages/promise/async_.py in wait(self, promise, timeout)
#     115                 # fulfilled or rejected
#     116                 return
# --> 117         target.scheduler.wait(target, timeout)
#     118
#     119     def drain_queues(self):
#
# ~/miniforge3/envs/pytorch_m1/lib/python3.8/site-packages/promise/schedulers/immediate.py in wait(self, promise, timeout)
#      23
#      24         promise._then(on_resolve_or_reject, on_resolve_or_reject)
# ---> 25         waited = e.wait(timeout)
#      26         if not waited:
#      27             raise Exception("Timeout")
#
# ~/miniforge3/envs/pytorch_m1/lib/python3.8/threading.py in wait(self, timeout)
#     556             signaled = self._flag
#     557             if not signaled:
# --> 558                 signaled = self._cond.wait(timeout)
#     559             return signaled
#     560
#
# ~/miniforge3/envs/pytorch_m1/lib/python3.8/threading.py in wait(self, timeout)
#     300         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     301             if timeout is None:
# --> 302                 waiter.acquire()
#     303                 gotit = True
#     304             else:
#
# KeyboardInterrupt:

# %%
def preprocess_data(image, label):
  image = tf.image.resize(image, (300,300))
  return tf.cast(image, tf.float32) / 255., label

# %%
# Create train/validation splits

# Shuffle dataset
dataset = data['train'].shuffle(1000)

train_split = 0.8
val_split = 0.2
train_size = int(train_split * DATASET_SIZE)
val_size = int(val_split * DATASET_SIZE)

train_data = dataset.take(train_size)
train_data  = train_data.map(preprocess_data)
train_data  = train_data.batch(64)

validation_data = dataset.skip(train_size)
validation_data  = validation_data.map(preprocess_data)
validation_data  = validation_data.batch(64)

# %%
feature_extractor_model = "inception_v3"

# %%
tf_hub_uri = f"https://tfhub.dev/google/imagenet/{feature_extractor_model}/feature_vector/5"

# %%
feature_extractor_layer = hub.KerasLayer(
    tf_hub_uri,
    trainable=False)

# %%
model = tf.keras.Sequential([
  feature_extractor_layer,
  tf.keras.layers.Dense(units=NUM_CLASSES)
])

# %%
model.compile(
  optimizer=tf.keras.optimizers.Adam(),
  loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
  metrics=['acc'])

model.fit(train_data, validation_data=validation_data, epochs=20)
